# %% [markdown]
# # Ejercicios visualización II

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# lo primero que hacemos es cargar el dataframe que vamos a usar para esta lección
df = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col=0) 
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions  ...  physicians_per_thousand  population  \
# 0          8.672  ...                     0.28         NaN
# ...

# %% [markdown]
# # ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

# %%
df_continentes = df.groupby("continent")["country"].count().reset_index()

# %%
# Añadir columna de porcentajes

df_continentes["porcentajes"]=round(df_continentes['country']/df.shape[0]*100,2)

# %%
df_continentes
# Out:
#          continent  country  porcentajes
# 0           Africa       53        27.18
# 1             Asia       45        23.08
# 2  Central America       20        10.26
# 3           Europe       47        24.10
# 4    North America        2         1.03
# 5          Oceania       14         7.18
# 6    South America       13         6.67

# %%
sns.scatterplot(x = "continent", 
                y = "porcentajes", 
                data = df_continentes, size =2, color="purple", hue_order="country")

# cambiamos los nombres de los ejes
plt.xlabel("Continente")
plt.ylabel("%")
plt.title("Porcentaje de paises por continente", fontsize=8);
